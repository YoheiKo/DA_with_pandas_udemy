# %% [markdown]
# # Pandas dataframes

# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")

# %% [markdown]
# ## Shared Methods and Attributes

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.tail(5)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape # This will return a python turple
# Out:
# (458, 9)

# %%
nba.dtypes # object means string
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
# ## Attributes not shared, exclusive to Dataframe

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info() ##Very useful summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# ## Diference between Shared Methods

# %%
rev = pd.read_csv("revenue.csv", index_col = "Date")
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
s = pd.Series([1,2,3])
s.sum()
# Out:
# 6

# %% [markdown]
# ## .sum()

# %%
rev.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = 0)
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = "index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = 1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
rev.sum(axis = "columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# ## Select a single column from a DataFrame

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.Name
# This returns a Series. #This works only when columns there's no space 
# Equivalent to nba["Name"]
Output = None

# %%
nba.Salary

Output = None

# %%
nba["Name"]
nba["Number"]
nba["Salary"]
Output = None

# %%
type(nba["Name"]) # This is a pandas series object
# Out:
# pandas.core.series.Series

# %%
nba["Name"].head() # method chaining
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %% [markdown]
# ## Select two or more Columns from Dataframe

# %%
nba[ ["Name", "Team"] ].head(5)
# Use [] square brackets to extract
# feed a list as an argument. We are going to get a new Dataframe
# Out:
#             Name            Team
# 0  Avery Bradley  Boston Celtics
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics
# 3    R.J. Hunter  Boston Celtics
# 4  Jonas Jerebko  Boston Celtics

# %%
nba[ ["Team", "Name"] ].head(5)
# Out:
#              Team           Name
# 0  Boston Celtics  Avery Bradley
# 1  Boston Celtics    Jae Crowder
# 2  Boston Celtics   John Holland
# 3  Boston Celtics    R.J. Hunter
# 4  Boston Celtics  Jonas Jerebko

# %%
nba[ ["Number", "College"] ].head(5)
# Out:
#    Number            College
# 0     0.0              Texas
# 1    99.0          Marquette
# 2    30.0  Boston University
# 3    28.0      Georgia State
# 4     8.0                NaN

# %%
nba[ ["Salary", "Team", "Name"] ].tail(5)
# Out:
#         Salary       Team          Name
# 453  2433333.0  Utah Jazz  Shelvin Mack
# 454   900000.0  Utah Jazz     Raul Neto
# 455  2900000.0  Utah Jazz  Tibor Pleiss
# 456   947276.0  Utah Jazz   Jeff Withey
# 457        NaN        NaN           NaN

# %%
select = ["Salary", "Team", "Name"]
nba[select].tail(5)
# Out:
#         Salary       Team          Name
# 453  2433333.0  Utah Jazz  Shelvin Mack
# 454   900000.0  Utah Jazz     Raul Neto
# 455  2900000.0  Utah Jazz  Tibor Pleiss
# 456   947276.0  Utah Jazz   Jeff Withey
# 457        NaN        NaN           NaN

# %% [markdown]
# ## Add a new column to DataFrame

# %%
# nba["Sport"] #This returns an error 
nba["Sport"] = "Basketball" #Assign "Basketball" to ["Sport"]

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba["Leage"] = "NBA"

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport Leage
# 0              Texas  7730337.0  Basketball   NBA
# 1          Marquette  6796117.0  Basketball   NBA
# 2  Boston University        NaN  Basketball   NBA

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.insert(3, column = "Sport", value = "Basketball")
nba.head(3)
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN

# %%
nba.insert(7, column = "Leage", value = "NBA")
nba.head(3)
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#   Leage  Weight            College     Salary
# 0   NBA   180.0              Texas  7730337.0
# 1   NBA   235.0          Marquette  6796117.0
# 2   NBA   205.0  Boston University        NaN

# %% [markdown]
# ## Broadcasting

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Age"]
nba["Age"].add(5) #You can add 5 to NaN value, but pandas keep NaN
nba["Age"] + 5 # Add 5 to every value in this series

nba["Salary"].sub(5000000) #subtract
nba["Salary"] - 5000000 # subtract 5m from every value

nba["Weight"].mul(0.453592)
nba["Weight in kg"] = nba["Weight"] * 0.453592 #generate a brand new series
# Out:
# 0       81.646560
# 1      106.594120
# 2       92.986360
# 3       83.914520
# 4      104.779752
# 5      108.862080
# 6      106.594120
# 7      107.954896
# 8       86.182480
# 9       99.790240
# 10     117.933920
# 11      83.914520
# 12      99.790240
# 13      97.522280
# 14     114.758776
# 15      97.975872
# 16      86.182480
# 17      90.718400
# 18      99.790240
# 19      90.718400
# 20      94.347136
# 21      99.336648
# 22      79.378600
# 23     124.737800
# 24      90.718400
# 25      99.790240
# 26     107.501304
# 27     112.490816
# 28      92.986360
# 29     100.243832
#           ...
# 428     97.522280
# 429     93.439952
# 430     95.254320
# 431    108.862080
# 432     97.522280
# 433     97.522280
# 434    120.201880
# 435    111.130040
# 436     88.450440
# 437     90.718400
# 438     83.914520
# 439    106.594120
# 440     78.471416
# 441    108.862080
# 442    103.418976
# 443     86.636072
# 444     97.068688
# 445     86.182480
# 446    120.201880
# ...

# %% [markdown]
# ## Create a new column from existing  column

# %%
nba["Weight in kg"] = nba["Weight"] * 0.453592 #generate a brand new series

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in kg
# 0              Texas  7730337.0      81.64656
# 1          Marquette  6796117.0     106.59412
# 2  Boston University        NaN      92.98636

# %%
nba["Salary in m"] = nba["Salary"] / 1000000

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in kg  Salary in m
# 0              Texas  7730337.0      81.64656     7.730337
# 1          Marquette  6796117.0     106.59412     6.796117
# 2  Boston University        NaN      92.98636          NaN

# %% [markdown]
# ## A review of the .value_counts() Method
# - count of uniquie value in a sinle column

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
#Frequency of unique value in each columns
nba["Team"].value_counts()
nba["Position"].value_counts()
nba["Weight"].value_counts()
nba["Salary"].value_counts()
Output = None

# %% [markdown]
# ## Drop rows with null value

# %%
nba = pd.read_csv("nba.csv")
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dtypes
Output = None

# %%
nba.info
Output = None

# %%
nba.dropna() #This drop all rows where there is one or more NaN value
nba.dropna(how = "all", inplace = True) # Remove rows if all of the values are NaN
# You can set inplace to True

# %%
nba.dropna(axis=1).head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.dropna(subset = ["Salary"]).head(3) #Drop out rows which has NaN in Salary
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0

# %%
nba.dropna(subset = ["Salary", "College"]).head(3) #Drop out rows which has NaN in Salary
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0

# %% [markdown]
# ## Fill in Null Values with the .fillna() Methdo

# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.fillna(0).head(5) # replace all NaN with 0
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                  0  5000000.0

# %%
nba["Salary"].fillna(0, inplace = True) #Select "only Salary" column and replace NaN with 0
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba["College"].fillna("No College", inplace = True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %% [markdown]
# ## The .astype() Method

# %%
import pandas as pd
nba = pd.read_csv("nba.csv").dropna(how = "all")
nba["Salary"].fillna(0, inplace = True)
nba["College"].fillna("None", inplace = True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4               None  5000000.0

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null category
# Number      457 non-null int64
# Position    457 non-null category
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int64
# dtypes: category(2), float64(1), int64(3), object(3)
# memory usage: 31.1+ KB

# %%
nba["Salary"] = nba["Salary"].astype("int")  #.astype() method doesn't have intype, so we have to reassign it "Salary" series
nba.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4               None  5000000

# %%
nba["Age"] = nba["Age"].astype("int")
nba["Number"] = nba["Number"].astype("int")
nba.head(3)
# nba.astype("float")
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %% [markdown]
# ## Category data type.
# * Reduce memory usage when you have a amall number of unique values

# %%
nba["Position"].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"] = nba["Position"].astype("category")

# %%
nba["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Milwaukee Bucks           16
# New York Knicks           16
# Dallas Mavericks          15
# Washington Wizards        15
# Detroit Pistons           15
# Sacramento Kings          15
# Boston Celtics            15
# Philadelphia 76ers        15
# Chicago Bulls             15
# Golden State Warriors     15
# San Antonio Spurs         15
# Oklahoma City Thunder     15
# Miami Heat                15
# Los Angeles Lakers        15
# Charlotte Hornets         15
# Los Angeles Clippers      15
# Atlanta Hawks             15
# Denver Nuggets            15
# Utah Jazz                 15
# Houston Rockets           15
# Portland Trail Blazers    15
# Brooklyn Nets             15
# Cleveland Cavaliers       15
# Phoenix Suns              15
# Indiana Pacers            15
# Toronto Raptors           15
# Minnesota Timberwolves    14
# Orlando Magic             14
# Name: Team, dtype: int64

# %%
nba["Team"].nunique()
# Out:
# 30

# %%
nba["Team"] = nba["Team"].astype("category")

# %% [markdown]
# ## Sort a DataFrame with th .sort_values() Method

# %%
import pandas as pd
nba = pd.read_csv("nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.sort_values("Name").head(10)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312       Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# 330     Al Jefferson       Charlotte Hornets    25.0        C  31.0   6-10
# 428  Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0    6-9
# 368    Alan Anderson      Washington Wizards     6.0       SG  33.0    6-6
# 135    Alan Williams            Phoenix Suns    15.0        C  23.0    6-8
# 444       Alec Burks               Utah Jazz    10.0       SG  24.0    6-6
#
#      Weight           College      Salary
# 152   161.0            Oregon   2250000.0
# 356   220.0           Arizona   4171680.0
# ...

# %%
nba.sort_values("Name", ascending = False).head(10)
# Out:
#                     Name                    Team  Number Position   Age  \
# 237        Zaza Pachulia        Dallas Mavericks    27.0        C  32.0
# 271        Zach Randolph       Memphis Grizzlies    50.0       PF  34.0
# 402          Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0
# 270       Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
# 386      Wilson Chandler          Denver Nuggets    21.0       SF  29.0
# 25           Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 141  Willie Cauley-Stein        Sacramento Kings     0.0        C  22.0
# 385          Will Barton          Denver Nuggets     5.0       SF  25.0
# 233      Wesley Matthews        Dallas Mavericks    23.0       SG  29.0
# 97        Wesley Johnson    Los Angeles Clippers    33.0       SF  28.0
#
#     Height  Weight         College      Salary
# 237   6-11   275.0             NaN   5200000.0
# 271    6-9   260.0  Michigan State   9638555.0
# ...

# %%
nba.sort_values("Age").head(5)
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 226       Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 122        Devin Booker            Phoenix Suns     1.0       SG  19.0    6-6
# 40   Kristaps Porzingis         New York Knicks     6.0       PF  20.0    7-3
# 401          Tyus Jones  Minnesota Timberwolves     1.0       PG  20.0    6-2
# 427     Cliff Alexander  Portland Trail Blazers    34.0       PF  20.0    6-8
#
#      Weight   College     Salary
# 226   202.0      UNLV  1733040.0
# 122   206.0  Kentucky  2127840.0
# 40    240.0       NaN  4131720.0
# 401   195.0      Duke  1282080.0
# 427   240.0    Kansas   525093.0

# %%
nba.sort_values("Age", ascending = False).head(5)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 304    Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
# 400   Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 298      Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
# 261    Vince Carter       Memphis Grizzlies    15.0       SG  39.0    6-6
# 102  Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
#
#      Weight         College     Salary
# 304   200.0            Utah   250750.0
# 400   240.0             NaN  8500000.0
# 298   250.0     Wake Forest  5250000.0
# 261   220.0  North Carolina  4088019.0
# 102   185.0             NaN   947726.0

# %%
nba.sort_values("Salary", ascending = False).head(5)  #NaN will be placed at the very end
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard      Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh           Miami Heat     1.0       PF  32.0   6-11
#
#      Weight       College      Salary
# 109   212.0           NaN  25000000.0
# 169   250.0           NaN  22970500.0
# 33    240.0      Syracuse  22875000.0
# 251   265.0           NaN  22359364.0
# 339   235.0  Georgia Tech  22192730.0

# %%
nba.sort_values("Salary", ascending = False).tail() #NaN will be placed at the very end
# Out:
#               Name                    Team  Number Position   Age Height  \
# 350  Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353  Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397   Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409     Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457            NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College  Salary
# 350   165.0  Virginia Commonwealth     NaN
# 353   205.0                    NaN     NaN
# 397   210.0                    NaN     NaN
# 409   250.0           Fresno State     NaN
# 457     NaN                    NaN     NaN

# %%
nba.sort_values(["Team", "Name"]).head(30) #both "Team" and  "Name" in alphabetic order
# Out:
#                  Name            Team  Number Position   Age Height  Weight  \
# 312        Al Horford   Atlanta Hawks    15.0        C  30.0   6-10   245.0
# 318   Dennis Schroder   Atlanta Hawks    17.0       PG  22.0    6-1   172.0
# 323       Jeff Teague   Atlanta Hawks     0.0       PG  27.0    6-2   186.0
# 309     Kent Bazemore   Atlanta Hawks    24.0       SF  26.0    6-5   201.0
# 311      Kirk Hinrich   Atlanta Hawks    12.0       SG  35.0    6-4   190.0
# 313    Kris Humphries   Atlanta Hawks    43.0       PF  31.0    6-9   235.0
# 314       Kyle Korver   Atlanta Hawks    26.0       SG  35.0    6-7   212.0
# 317   Lamar Patterson   Atlanta Hawks    13.0       SG  24.0    6-5   225.0
# 316      Mike Muscala   Atlanta Hawks    31.0       PF  24.0   6-11   240.0
# 319        Mike Scott   Atlanta Hawks    32.0       PF  27.0    6-8   237.0
# 315      Paul Millsap   Atlanta Hawks     4.0       PF  31.0    6-8   246.0
# ...

# %%
nba.sort_values(["Team", "Name"], ascending = False).head(30) #both "Team" and  "Name" in reverse alphabetic order
# Out:
#                 Name                Team  Number Position   Age Height  \
# 379   Ramon Sessions  Washington Wizards     7.0       PG  30.0    6-3
# 378  Otto Porter Jr.  Washington Wizards    22.0       SF  23.0    6-8
# 375     Nene Hilario  Washington Wizards    42.0        C  33.0   6-11
# 376  Markieff Morris  Washington Wizards     5.0       PF  26.0   6-10
# 381  Marcus Thornton  Washington Wizards    15.0       SF  29.0    6-4
# 373    Marcin Gortat  Washington Wizards    13.0        C  32.0   6-11
# 377  Kelly Oubre Jr.  Washington Wizards    12.0       SF  20.0    6-7
# 382        John Wall  Washington Wizards     2.0       PG  25.0    6-4
# 371     Jarell Eddie  Washington Wizards     8.0       SG  24.0    6-7
# 370     Jared Dudley  Washington Wizards     1.0       SF  30.0    6-7
# 374       JJ Hickson  Washington Wizards    21.0        C  27.0    6-9
# 380   Garrett Temple  Washington Wizards    17.0       SG  30.0    6-6
# ...

# %%
nba.sort_values(["Team", "Name"], ascending = [True, False], inplace = True)
nba.head(30) # "Team" in alphabetic order and "Name" in reverse alphabetic order
# Out:
#                  Name            Team  Number Position   Age Height  Weight  \
# 322    Walter Tavares   Atlanta Hawks    22.0        C  24.0    7-3   260.0
# 310  Tim Hardaway Jr.   Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 321    Tiago Splitter   Atlanta Hawks    11.0        C  31.0   6-11   245.0
# 320   Thabo Sefolosha   Atlanta Hawks    25.0       SF  32.0    6-7   220.0
# 315      Paul Millsap   Atlanta Hawks     4.0       PF  31.0    6-8   246.0
# 319        Mike Scott   Atlanta Hawks    32.0       PF  27.0    6-8   237.0
# 316      Mike Muscala   Atlanta Hawks    31.0       PF  24.0   6-11   240.0
# 317   Lamar Patterson   Atlanta Hawks    13.0       SG  24.0    6-5   225.0
# 314       Kyle Korver   Atlanta Hawks    26.0       SG  35.0    6-7   212.0
# 313    Kris Humphries   Atlanta Hawks    43.0       PF  31.0    6-9   235.0
# 311      Kirk Hinrich   Atlanta Hawks    12.0       SG  35.0    6-4   190.0
# ...

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values(["Number", "Salary", "Name"], inplace = True)
nba.tail(3)
# Out:
#                Name             Team  Number Position   Age Height  Weight  \
# 68   Lucas Nogueira  Toronto Raptors    92.0        C  23.0    7-0   220.0
# 1       Jae Crowder   Boston Celtics    99.0       SF  25.0    6-6   235.0
# 457             NaN              NaN     NaN      NaN   NaN    NaN     NaN
#
#        College     Salary
# 68         NaN  1842000.0
# 1    Marquette  6796117.0
# 457        NaN        NaN

# %%
nba.sort_index().head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.sort_index(ascending = False, inplace = True)
nba.head()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
#
#         Salary
# 457        NaN
# 456   947276.0
# 455  2900000.0
# 454   900000.0
# 453  2433333.0

# %% [markdown]
# ## Rank Vaues with the .rank() Method

# %%
nba = pd.read_csv("nba.csv").dropna(how = "all") #knock out the last row
nba["Salary"] = nba["Salary"].fillna(0).astype("int") #fill NA with zero and convert float to integers
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
#Rank method is called on a single series
nba["Salary Rank"] = nba["Salary"].rank(ascending = False).astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452

# %%
nba.sort_values(by = "Salary Rank").head(5)
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard      Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh           Miami Heat     1.0       PF  32.0   6-11
#
#      Weight       College    Salary  Salary Rank
# 109   212.0           NaN  25000000            1
# 169   250.0           NaN  22970500            2
# 33    240.0      Syracuse  22875000            3
# 251   265.0           NaN  22359364            4
# 339   235.0  Georgia Tech  22192730            5
